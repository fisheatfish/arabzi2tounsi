# %% [markdown]
# # arabzi2tounsi — Fine-tuning sur Colab
# Lance les cellules dans l'ordre.

# %%
# 1. Cloner le repo (repo privé via secret Colab)
# Ajoute ton token dans : icône 🔑 panneau gauche → GITHUB_TOKEN
from google.colab import userdata
token = userdata.get("GITHUB_TOKEN")
# !git clone https://{token}@github.com/fish_eat_fish/arabzi2tounsi.git
# %cd arabzi2tounsi

# %%
# 2. Installer les dépendances
# !pip install -q torch transformers datasets peft trl accelerate

# %%
# 3. Préparer les splits train / val / test
# !python 01_prepare_dataset.py

# %%
# 4. Vérifier que le GPU est disponible
import torch
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'Pas de GPU — va dans Exécution > Modifier le type d\'exécution')

# %%
# 5. Lancer le fine-tuning
# !python 02_train.py
